# %%
P1 = Polyhedron(vertices=[(5.0, 10.0, 0.0), (1.4857142857142858, 10.0, 2.0), (3.4285714285714284, 10.0, 0.0), (2.657210401891253, 4.874704491725768, 2.0), (4.633569739952718, 4.7281323877068555, 0.0), (5.0, 4.615384615384615, 0.0), (4.245614035087719, 4.385964912280702, 2.0), (5.0, 4.233870967741935, 1.653225806451613), (2.0, 10.0, 2.0), (5.0, 10.0, 0.5)])
P1.plot()
# Out:
# Graphics3d Object

# %%
from sage.plot.plot3d.shapes2 import Line
l1 = line3d([(5.0, 10.0, 0.0), (1.4857142857142858, 10.0, 2.0)], thickness=2, color=(1,0,0), arrow_head=True)

L = []
L.append(line3d([(5.0, 10.0, 0.0), (3.4285714285714284, 10.0, 0.0)], thickness=2, color=(1,0,0), arrow_head=True))
L.append(line3d([(5.0, 10.0, 0.5), (5.0, 10.0, 0.0)], thickness=2, color=(1,0,0), arrow_head=True))
L.append(line3d([(5.0, 10.0, 0.0), (5.0, 4.615384615384615, 0.0)], thickness=2, color=(1,0,0), arrow_head=True))
L.append(line3d([(5.0, 10.0, 0.5), (2.0, 10.0, 2.0)], thickness=2, color=(1,0,0), arrow_head=True))
L.append(line3d([(5.0, 10.0, 0.5), (5.0, 4.233870967741935, 1.653225806451613)], thickness=2, color=(1,0,0), arrow_head=True))
L.append(line3d([(3.4285714285714284, 10.0, 0.0), (1.4857142857142858, 10.0, 2.0)], thickness=2, color=(1,0,0), arrow_head=True))
L.append(line3d([(5.0, 4.233870967741935, 1.653225806451613), (4.245614035087719, 4.385964912280702, 2.0)], thickness=2, color=(1,0,0), arrow_head=True))
L.append(line3d([(1.4857142857142858, 10.0, 2.0), (2.657210401891253, 4.874704491725768, 2.0)], thickness=2, color=(1,0,0), arrow_head=True))
L.append(line3d([(5.0, 4.615384615384615, 0.0), (4.633569739952718, 4.7281323877068555, 0.0)], thickness=2, color=(1,0,0), arrow_head=True))

P1.plot() + sum([l.plot() for l in L])
# Out:
# Graphics3d Object
